# %%
# !pip install PyFlyt stable-baselines3
# Out:
# Collecting PyFlyt
#   Downloading pyflyt-0.29.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.9.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from PyFlyt) (0.60.0)
# Collecting numpy<2.0.0 (from PyFlyt)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from PyFlyt) (1.16.3)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (from PyFlyt) (1.3.0)
# Collecting pettingzoo (from PyFlyt)
#   Downloading pettingzoo-1.26.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting pybullet (from PyFlyt)
#   Downloading pybullet-3.2.7.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 32.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from PyFlyt) (6.0.3)
# Requirement already satisfied: torch<3.0,>=2.8 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.11.0+cu128)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium->PyFlyt) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium->PyFlyt) (0.0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.29.7)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0,>=2.8->stable-baselines3) (12.8.90)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->PyFlyt) (0.43.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch<3.0,>=2.8->stable-baselines3) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.8->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.8->stable-baselines3) (3.0.3)
# Downloading pyflyt-0.29.0-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 20.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.9.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 20.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 132.2 MB/s eta 0:00:00
# Downloading pettingzoo-1.26.1-py3-none-any.whl (805 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.5/805.5 kB 55.7 MB/s eta 0:00:00
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.7-cp312-cp312-linux_x86_64.whl size=99873464 sha256=bcefa31ecff2d9725fd791ed27ad00f7e28ebf174e7435f5b398515ce930eca9
#   Stored in directory: /root/.cache/pip/wheels/72/95/1d/b336e5ee612ae9a019bfff4dc0bedd100ee6f0570db205fdf8
# Successfully built pybullet
# Installing collected packages: pybullet, numpy, pettingzoo, PyFlyt, stable-baselines3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed PyFlyt-0.29.0 numpy-1.26.4 pettingzoo-1.26.1 pybullet-3.2.7 stable-baselines3-2.9.0

# %%
import PyFlyt
import gymnasium as gym
import stable_baselines3 as sb3
from importlib.metadata import version

print("PyFlyt version:", version("PyFlyt"))
print("Gymnasium version:", gym.__version__)
print("Stable-Baselines3 version:", sb3.__version__)
# Out:
# PyFlyt version: 0.29.0
# Gymnasium version: 1.3.0
# Stable-Baselines3 version: 2.9.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import numpy as np
import gymnasium as gym
from gymnasium import spaces


class FlattenWaypointObs(gym.ObservationWrapper):
    """Flattens the Dict observation into a fixed 24-dim vector: [attitude(21), next_target_delta(3)]."""

    def __init__(self, env):
        super().__init__(env)
        attitude_dim = env.observation_space["attitude"].shape[0]
        flat_dim = attitude_dim + 3
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(flat_dim,), dtype=np.float64
        )

    def observation(self, obs):
        attitude = obs["attitude"]
        target_deltas = obs["target_deltas"]
        next_delta = target_deltas[0] if len(target_deltas) > 0 else np.zeros(3, dtype=np.float64)
        return np.concatenate([attitude, next_delta]).astype(np.float64)


class ClipAction(gym.ActionWrapper):
    """Clips the agent's raw action into the environment's valid action bounds."""

    def __init__(self, env):
        super().__init__(env)
        self.low = env.action_space.low
        self.high = env.action_space.high

    def action(self, action):
        return np.clip(action, self.low, self.high)

# %%
import PyFlyt.gym_envs
from stable_baselines3.common.monitor import Monitor


def make_env():
    """Builds the fully wrapped, SB3-compatible training environment."""
    env = gym.make("PyFlyt/QuadX-Waypoints-v4", render_mode=None)
    env = FlattenWaypointObs(env)   # dict -> 24-dim vector
    env = ClipAction(env)           # clip actions to valid bounds
    env = Monitor(env)              # SB3 episode stat logging
    return env


# Quick sanity check on the wrapped env
env = make_env()
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)

obs, info = env.reset(seed=0)
print("Obs shape:", obs.shape)
# Out:
# Observation space: Box(-inf, inf, (24,), float64)
# Action space: Box([-3.14159265 -3.14159265 -3.14159265  0.        ], [3.14159265 3.14159265 3.14159265 0.8       ], (4,), float64)
#
# Obs shape: (24,)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from stable_baselines3 import PPO

# Create the PPO model with SB3's well-tested defaults
model = PPO(
    "MlpPolicy",           # standard MLP actor-critic, matches our hand-written one
    env,
    verbose=1,             # print training logs (ep_rew_mean etc.)
    device="cpu",          # PyBullet is CPU-bound; GPU gives little benefit here
    seed=0,
)

# First training run: 200k timesteps
model.learn(total_timesteps=200_000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | -92.8    |
# | time/              |          |
# |    fps             | 219      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.7        |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008801786 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 902         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 1           |
# |    value_loss           | 2e+03       |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | -95.9        |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 3            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0078123314 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.0429       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 666          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.994        |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 41.2      |
# |    ep_rew_mean          | -94.8     |
# | time/                   |           |
# |    fps                  | 207       |
# |    iterations           | 4         |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0108414 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.64     |
# |    explained_variance   | 0.00853   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 607       |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.0171   |
# |    std                  | 0.989     |
# |    value_loss           | 1.15e+03  |
# ---------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45         |
# |    ep_rew_mean          | -94.7      |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 5          |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01087256 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.63      |
# |    explained_variance   | 0.00457    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 421        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.988      |
# |    value_loss           | 843        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48         |
# |    ep_rew_mean          | -94.7      |
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 6          |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00828211 |
# |    clip_fraction        | 0.0812     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.61      |
# |    explained_variance   | 0.0015     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 239        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.014     |
# |    std                  | 0.982      |
# |    value_loss           | 638        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | -93.1       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 7           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010238871 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.00154     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 187         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.985       |
# |    value_loss           | 494         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.7        |
# |    ep_rew_mean          | -90         |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 8           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012257436 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | -0.00761    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.971       |
# |    value_loss           | 370         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -88.4       |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 9           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009028565 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.04        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.97        |
# |    value_loss           | 373         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64          |
# |    ep_rew_mean          | -86.9       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 10          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010041213 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.962       |
# |    value_loss           | 268         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.9        |
# |    ep_rew_mean          | -87.8       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 11          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009124324 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.961       |
# |    value_loss           | 254         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.4        |
# |    ep_rew_mean          | -85.8       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 12          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011175463 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70          |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.96        |
# |    value_loss           | 168         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.3        |
# |    ep_rew_mean          | -82.3       |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 13          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010654837 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.957       |
# |    value_loss           | 160         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78          |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 14          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011766899 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.957       |
# |    value_loss           | 160         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.3         |
# |    ep_rew_mean          | -83.4        |
# | time/                   |              |
# |    fps                  | 223          |
# |    iterations           | 15           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0093479045 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.6         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0195      |
# |    std                  | 0.959        |
# |    value_loss           | 93.3         |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.6        |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 16          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009550951 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.961       |
# |    value_loss           | 96.6        |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | -86.4       |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 17          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012363177 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.959       |
# |    value_loss           | 67          |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.7        |
# |    ep_rew_mean          | -84.4       |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 18          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010030216 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.951       |
# |    value_loss           | 64.7        |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.7        |
# |    ep_rew_mean          | -79.3       |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 19          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009246574 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.954       |
# |    value_loss           | 112         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.2        |
# |    ep_rew_mean          | -78.7       |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 20          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010913402 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.952       |
# |    value_loss           | 196         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -77.9        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 21           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0110306665 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0188      |
# |    std                  | 0.953        |
# |    value_loss           | 90.1         |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -75.9       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 22          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009725118 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.951       |
# |    value_loss           | 84.2        |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -76.6       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 23          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009619801 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.95        |
# |    value_loss           | 112         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -80         |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 24          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010029145 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.943       |
# |    value_loss           | 99.7        |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 111        |
# |    ep_rew_mean          | -79.1      |
# | time/                   |            |
# |    fps                  | 231        |
# |    iterations           | 25         |
# |    time_elapsed         | 220        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00993878 |
# |    clip_fraction        | 0.0958     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.43      |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75.6       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0176    |
# |    std                  | 0.938      |
# |    value_loss           | 157        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -79.5       |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 26          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010422336 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.93        |
# |    value_loss           | 91.3        |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | -78.7       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 27          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011482077 |
# ...
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 85          |
# |    time_elapsed         | 689         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.011992393 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.1        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.783       |
# |    value_loss           | 97.3        |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 86          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.014858969 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.773       |
# |    value_loss           | 187         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 87          |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.014406858 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.6        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.769       |
# |    value_loss           | 110         |
# -----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 287        |
# |    ep_rew_mean          | 142        |
# | time/                   |            |
# |    fps                  | 252        |
# |    iterations           | 88         |
# |    time_elapsed         | 712        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01579082 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.61      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 66.1       |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.766      |
# |    value_loss           | 102        |
# ----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 285        |
# |    ep_rew_mean          | 151        |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 89         |
# |    time_elapsed         | 720        |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.01717256 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.59      |
# |    explained_variance   | 0.765      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.2       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0201    |
# |    std                  | 0.763      |
# |    value_loss           | 106        |
# ----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 90          |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.011907829 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.761       |
# |    value_loss           | 286         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 91          |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.012376079 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.759       |
# |    value_loss           | 234         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 92          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011711816 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.6        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.761       |
# |    value_loss           | 237         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 93          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.013406055 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.3        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.755       |
# |    value_loss           | 105         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 284        |
# |    ep_rew_mean          | 166        |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 94         |
# |    time_elapsed         | 758        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.01497914 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.9       |
# |    n_updates            | 930        |
# |    policy_gradient_loss | -0.0211    |
# |    std                  | 0.751      |
# |    value_loss           | 79.5       |
# ----------------------------------------
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 285          |
# |    ep_rew_mean          | 171          |
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 95           |
# |    time_elapsed         | 766          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0118807275 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0155      |
# |    std                  | 0.75         |
# |    value_loss           | 212          |
# ------------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 96          |
# |    time_elapsed         | 774         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016160047 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.753       |
# |    value_loss           | 82.8        |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 97          |
# |    time_elapsed         | 782         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.013461754 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.757       |
# |    value_loss           | 157         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 98          |
# |    time_elapsed         | 789         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.012518497 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.4        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.754       |
# |    value_loss           | 204         |
# -----------------------------------------

# %%
# Save the trained model FIRST — protect the 200k training result
model.save("ppo_quadx_waypoints_200k")

import os
size_mb = os.path.getsize("ppo_quadx_waypoints_200k.zip") / 1e6
print(f"Model saved: ppo_quadx_waypoints_200k.zip ({size_mb:.2f} MB)")
# Out:
# Model saved: ppo_quadx_waypoints_200k.zip (0.18 MB)

# %%
import numpy as np
import imageio

# Build a separate env with RGB rendering (training env had render_mode=None)
render_env = gym.make("PyFlyt/QuadX-Waypoints-v4", render_mode="rgb_array")
render_env = FlattenWaypointObs(render_env)
render_env = ClipAction(render_env)
# NOTE: no Monitor here — we don't need episode logging for rendering

# Record one episode with the trained policy
obs, info = render_env.reset(seed=42)
frames = []
terminated = False
truncated = False
total_reward = 0.0

while not (terminated or truncated):
    frame = render_env.render()
    frames.append(frame[:, :, :3])  # drop alpha channel (RGBA -> RGB)

    # Use the trained model to pick actions (deterministic for clean evaluation)
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = render_env.step(action)
    total_reward += reward

# Capture the final frame
frames.append(render_env.render()[:, :, :3])

print(f"Episode finished: {len(frames)} frames")
print(f"Total reward: {total_reward:.1f}")
print(f"Targets reached: {info['num_targets_reached']}")
print(f"Out of bounds: {info['out_of_bounds']} | Collision: {info['collision']}")

# Save as video
imageio.mimsave("trained_agent.mp4", frames, fps=30)
print("Saved to trained_agent.mp4")
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/utils/passive_env_checker.py:282: UserWarning: WARN: RGB-array rendering should return a numpy array in which the last axis has three dimensions, got 4
#   logger.warn(
# Episode finished: 303 frames
# Total reward: 316.8
# Targets reached: 1
# Out of bounds: False | Collision: False
# Saved to trained_agent.mp4

# %%
from IPython.display import Video
Video("trained_agent.mp4", embed=True, width=480)
# Out:
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Numerical evaluation over multiple episodes — more reliable than one video
NUM_EVAL_EPISODES = 20

eval_env = make_env()

episode_rewards = []
episode_targets = []
episode_oob = []
episode_lengths = []

for ep in range(NUM_EVAL_EPISODES):
    obs, info = eval_env.reset(seed=1000 + ep)
    terminated = truncated = False
    ep_reward = 0.0
    ep_len = 0

    while not (terminated or truncated):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        ep_reward += reward
        ep_len += 1

    episode_rewards.append(ep_reward)
    episode_targets.append(info["num_targets_reached"])
    episode_oob.append(info["out_of_bounds"])
    episode_lengths.append(ep_len)

import numpy as np
print(f"Episodes evaluated: {NUM_EVAL_EPISODES}")
print(f"Mean reward:        {np.mean(episode_rewards):.1f} +/- {np.std(episode_rewards):.1f}")
print(f"Mean targets:       {np.mean(episode_targets):.2f} (max possible: 4)")
print(f"Mean episode len:   {np.mean(episode_lengths):.1f}")
print(f"Out-of-bounds rate: {np.mean(episode_oob) * 100:.0f}%")
print(f"Targets per episode: {episode_targets}")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Episodes evaluated: 20
# Mean reward:        228.3 +/- 150.0
# Mean targets:       0.70 (max possible: 4)
# Mean episode len:   278.0
# Out-of-bounds rate: 0%
# Targets per episode: [0, 3, 0, 0, 1, 0, 0, 0, 2, 1, 1, 0, 0, 0, 0, 3, 0, 2, 0, 1]

# %%
  from stable_baselines3 import PPO

  single_env = make_env()

  model_v2 = PPO(
      "MlpPolicy",
      single_env,
      verbose=1,
      device="cpu",
      seed=0,
  )

  model_v2.learn(total_timesteps=1_000_000)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# |    value_loss           | 604         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 506         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 326         |
# |    time_elapsed         | 10035       |
# |    total_timesteps      | 667648      |
# | train/                  |             |
# |    approx_kl            | 0.050428897 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.2        |
# |    n_updates            | 3250        |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.35        |
# |    value_loss           | 254         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 507         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 327         |
# |    time_elapsed         | 10067       |
# |    total_timesteps      | 669696      |
# | train/                  |             |
# |    approx_kl            | 0.050369054 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 3260        |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.348       |
# |    value_loss           | 321         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 515         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 328         |
# |    time_elapsed         | 10099       |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.033862576 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.1        |
# |    n_updates            | 3270        |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.349       |
# |    value_loss           | 303         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 504         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 329         |
# |    time_elapsed         | 10131       |
# |    total_timesteps      | 673792      |
# | train/                  |             |
# |    approx_kl            | 0.033565484 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 239         |
# |    n_updates            | 3280        |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.35        |
# |    value_loss           | 462         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 506         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 330         |
# |    time_elapsed         | 10162       |
# |    total_timesteps      | 675840      |
# | train/                  |             |
# |    approx_kl            | 0.053970106 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.4        |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.348       |
# |    value_loss           | 360         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 254       |
# |    ep_rew_mean          | 501       |
# | time/                   |           |
# |    fps                  | 66        |
# |    iterations           | 331       |
# |    time_elapsed         | 10194     |
# |    total_timesteps      | 677888    |
# | train/                  |           |
# |    approx_kl            | 0.0331026 |
# |    clip_fraction        | 0.327     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42     |
# |    explained_variance   | 0.672     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 188       |
# |    n_updates            | 3300      |
# |    policy_gradient_loss | -0.0188   |
# |    std                  | 0.349     |
# |    value_loss           | 404       |
# ---------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 332         |
# |    time_elapsed         | 10225       |
# |    total_timesteps      | 679936      |
# | train/                  |             |
# |    approx_kl            | 0.043145224 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 3310        |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.349       |
# |    value_loss           | 402         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 495         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 333         |
# |    time_elapsed         | 10256       |
# |    total_timesteps      | 681984      |
# | train/                  |             |
# |    approx_kl            | 0.054014403 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.2        |
# |    n_updates            | 3320        |
# |    policy_gradient_loss | -0.00997    |
# |    std                  | 0.348       |
# |    value_loss           | 295         |
# -----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 257        |
# |    ep_rew_mean          | 495        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 334        |
# |    time_elapsed         | 10287      |
# |    total_timesteps      | 684032     |
# | train/                  |            |
# |    approx_kl            | 0.04697495 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.7        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32         |
# |    n_updates            | 3330       |
# |    policy_gradient_loss | -0.0172    |
# |    std                  | 0.347      |
# |    value_loss           | 282        |
# ----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 259        |
# |    ep_rew_mean          | 495        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 335        |
# |    time_elapsed         | 10319      |
# |    total_timesteps      | 686080     |
# | train/                  |            |
# |    approx_kl            | 0.05434349 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18         |
# |    n_updates            | 3340       |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 0.346      |
# |    value_loss           | 142        |
# ----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 336         |
# |    time_elapsed         | 10350       |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.038489267 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.6        |
# |    n_updates            | 3350        |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.344       |
# |    value_loss           | 233         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 491         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 337         |
# |    time_elapsed         | 10381       |
# |    total_timesteps      | 690176      |
# | train/                  |             |
# |    approx_kl            | 0.033883616 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 3360        |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.344       |
# |    value_loss           | 252         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 485         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 338         |
# |    time_elapsed         | 10412       |
# |    total_timesteps      | 692224      |
# | train/                  |             |
# |    approx_kl            | 0.029866775 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 3370        |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.343       |
# |    value_loss           | 423         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 339         |
# |    time_elapsed         | 10443       |
# |    total_timesteps      | 694272      |
# | train/                  |             |
# |    approx_kl            | 0.027677111 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 3380        |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.343       |
# |    value_loss           | 400         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 477         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 340         |
# |    time_elapsed         | 10474       |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.052211575 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.9        |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.342       |
# |    value_loss           | 244         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 262        |
# |    ep_rew_mean          | 483        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 341        |
# |    time_elapsed         | 10506      |
# |    total_timesteps      | 698368     |
# | train/                  |            |
# |    approx_kl            | 0.04345271 |
# |    clip_fraction        | 0.32       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 163        |
# |    n_updates            | 3400       |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.34       |
# |    value_loss           | 364        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | 494         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 342         |
# |    time_elapsed         | 10537       |
# |    total_timesteps      | 700416      |
# | train/                  |             |
# |    approx_kl            | 0.028757557 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95          |
# |    n_updates            | 3410        |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.34        |
# |    value_loss           | 409         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 343        |
# |    time_elapsed         | 10568      |
# |    total_timesteps      | 702464     |
# | train/                  |            |
# |    approx_kl            | 0.04544505 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.706      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.2       |
# |    n_updates            | 3420       |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.339      |
# |    value_loss           | 331        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 344         |
# |    time_elapsed         | 10600       |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.035291143 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.5        |
# |    n_updates            | 3430        |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.337       |
# |    value_loss           | 477         |
# -----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 257         |
# |    ep_rew_mean          | 501         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 345         |
# |    time_elapsed         | 10631       |
# |    total_timesteps      | 706560      |
# | train/                  |             |
# |    approx_kl            | 0.041043162 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.6        |
# |    n_updates            | 3440        |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.335       |
# |    value_loss           | 284         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 346         |
# |    time_elapsed         | 10663       |
# |    total_timesteps      | 708608      |
# | train/                  |             |
# |    approx_kl            | 0.053618796 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 3450        |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.334       |
# |    value_loss           | 265         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 253        |
# |    ep_rew_mean          | 495        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 347        |
# |    time_elapsed         | 10695      |
# |    total_timesteps      | 710656     |
# | train/                  |            |
# |    approx_kl            | 0.03668268 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.639      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 150        |
# |    n_updates            | 3460       |
# |    policy_gradient_loss | -0.0148    |
# |    std                  | 0.334      |
# |    value_loss           | 426        |
# ----------------------------------------
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 498         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 348         |
# |    time_elapsed         | 10725       |
# |    total_timesteps      | 712704      |
# | train/                  |             |
# |    approx_kl            | 0.038469553 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.1        |
# |    n_updates            | 3470        |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.335       |
# |    value_loss           | 351         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 503         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 349         |
# |    time_elapsed         | 10757       |
# |    total_timesteps      | 714752      |
# | train/                  |             |
# |    approx_kl            | 0.043380536 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97          |
# |    n_updates            | 3480        |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.334       |
# |    value_loss           | 262         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 248        |
# |    ep_rew_mean          | 500        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 350        |
# |    time_elapsed         | 10788      |
# |    total_timesteps      | 716800     |
# | train/                  |            |
# |    approx_kl            | 0.03779441 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 93.8       |
# |    n_updates            | 3490       |
# |    policy_gradient_loss | -0.0167    |
# |    std                  | 0.335      |
# |    value_loss           | 632        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 503         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 351         |
# |    time_elapsed         | 10819       |
# |    total_timesteps      | 718848      |
# | train/                  |             |
# |    approx_kl            | 0.048157625 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 3500        |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.335       |
# |    value_loss           | 472         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 246        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 352        |
# |    time_elapsed         | 10851      |
# |    total_timesteps      | 720896     |
# | train/                  |            |
# |    approx_kl            | 0.03531654 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.731      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 103        |
# |    n_updates            | 3510       |
# |    policy_gradient_loss | -0.0196    |
# |    std                  | 0.336      |
# |    value_loss           | 475        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 247        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 353        |
# |    time_elapsed         | 10882      |
# |    total_timesteps      | 722944     |
# | train/                  |            |
# |    approx_kl            | 0.04971638 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.2       |
# |    n_updates            | 3520       |
# |    policy_gradient_loss | -0.0181    |
# |    std                  | 0.334      |
# |    value_loss           | 283        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 354         |
# |    time_elapsed         | 10914       |
# |    total_timesteps      | 724992      |
# | train/                  |             |
# |    approx_kl            | 0.039568428 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 3530        |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.332       |
# |    value_loss           | 274         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 507         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 355         |
# |    time_elapsed         | 10946       |
# |    total_timesteps      | 727040      |
# | train/                  |             |
# |    approx_kl            | 0.042432956 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.5        |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.332       |
# |    value_loss           | 396         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 505         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 356         |
# |    time_elapsed         | 10977       |
# |    total_timesteps      | 729088      |
# | train/                  |             |
# |    approx_kl            | 0.041412488 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.9        |
# |    n_updates            | 3550        |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.331       |
# |    value_loss           | 398         |
# -----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 251        |
# |    ep_rew_mean          | 507        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 357        |
# |    time_elapsed         | 11008      |
# |    total_timesteps      | 731136     |
# | train/                  |            |
# |    approx_kl            | 0.04403593 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.768      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.2       |
# |    n_updates            | 3560       |
# |    policy_gradient_loss | -0.0232    |
# |    std                  | 0.33       |
# |    value_loss           | 316        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 252        |
# |    ep_rew_mean          | 507        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 358        |
# |    time_elapsed         | 11039      |
# |    total_timesteps      | 733184     |
# | train/                  |            |
# |    approx_kl            | 0.05785339 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.772      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 159        |
# |    n_updates            | 3570       |
# |    policy_gradient_loss | -0.0218    |
# |    std                  | 0.328      |
# |    value_loss           | 262        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 512         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 359         |
# |    time_elapsed         | 11071       |
# |    total_timesteps      | 735232      |
# | train/                  |             |
# |    approx_kl            | 0.032184146 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 184         |
# |    n_updates            | 3580        |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.328       |
# |    value_loss           | 364         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 504         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 360         |
# |    time_elapsed         | 11102       |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.034435153 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77          |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.33        |
# |    value_loss           | 303         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 248        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 361        |
# |    time_elapsed         | 11133      |
# |    total_timesteps      | 739328     |
# | train/                  |            |
# |    approx_kl            | 0.06207698 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 89.8       |
# |    n_updates            | 3600       |
# |    policy_gradient_loss | -0.023     |
# |    std                  | 0.328      |
# |    value_loss           | 286        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 514        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 362        |
# |    time_elapsed         | 11164      |
# |    total_timesteps      | 741376     |
# | train/                  |            |
# |    approx_kl            | 0.04446541 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 97.8       |
# |    n_updates            | 3610       |
# |    policy_gradient_loss | -0.0146    |
# |    std                  | 0.328      |
# |    value_loss           | 295        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 507         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 363         |
# |    time_elapsed         | 11195       |
# |    total_timesteps      | 743424      |
# | train/                  |             |
# |    approx_kl            | 0.037688997 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 3620        |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.33        |
# |    value_loss           | 396         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 510         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 364         |
# |    time_elapsed         | 11226       |
# |    total_timesteps      | 745472      |
# | train/                  |             |
# |    approx_kl            | 0.037050404 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.2        |
# |    n_updates            | 3630        |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.328       |
# |    value_loss           | 296         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 510         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 365         |
# |    time_elapsed         | 11258       |
# |    total_timesteps      | 747520      |
# | train/                  |             |
# |    approx_kl            | 0.032778535 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 3640        |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.327       |
# |    value_loss           | 420         |
# -----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 247        |
# |    ep_rew_mean          | 508        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 366        |
# |    time_elapsed         | 11288      |
# |    total_timesteps      | 749568     |
# | train/                  |            |
# |    approx_kl            | 0.03189295 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.617      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 118        |
# |    n_updates            | 3650       |
# |    policy_gradient_loss | -0.0159    |
# |    std                  | 0.325      |
# |    value_loss           | 467        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# ...
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 476         |
# |    time_elapsed         | 14727       |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.052903943 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0599      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.24        |
# |    value_loss           | 580         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 474         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 477         |
# |    time_elapsed         | 14758       |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.047323935 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0692      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.241       |
# |    value_loss           | 362         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 470         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 478         |
# |    time_elapsed         | 14789       |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.087991275 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0612      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.6        |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.241       |
# |    value_loss           | 367         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 245        |
# |    ep_rew_mean          | 475        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 479        |
# |    time_elapsed         | 14822      |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.08272872 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0584     |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 198        |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.0265    |
# |    std                  | 0.241      |
# |    value_loss           | 343        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 247       |
# |    ep_rew_mean          | 488       |
# | time/                   |           |
# |    fps                  | 66        |
# |    iterations           | 480       |
# |    time_elapsed         | 14854     |
# |    total_timesteps      | 983040    |
# | train/                  |           |
# |    approx_kl            | 0.0591254 |
# |    clip_fraction        | 0.394     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.0594    |
# |    explained_variance   | 0.794     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 96.5      |
# |    n_updates            | 4790      |
# |    policy_gradient_loss | -0.0225   |
# |    std                  | 0.241     |
# |    value_loss           | 705       |
# ---------------------------------------
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 243        |
# |    ep_rew_mean          | 485        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 481        |
# |    time_elapsed         | 14885      |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.08126031 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0719     |
# |    explained_variance   | 0.781      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 80.6       |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.0221    |
# |    std                  | 0.24       |
# |    value_loss           | 323        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 239        |
# |    ep_rew_mean          | 480        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 482        |
# |    time_elapsed         | 14916      |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.05881102 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0915     |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 104        |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0224    |
# |    std                  | 0.239      |
# |    value_loss           | 471        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 481         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 483         |
# |    time_elapsed         | 14947       |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.065115675 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.103       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.239       |
# |    value_loss           | 467         |
# -----------------------------------------
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 240        |
# |    ep_rew_mean          | 488        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 484        |
# |    time_elapsed         | 14978      |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.06077282 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.112      |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 120        |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.0221    |
# |    std                  | 0.239      |
# |    value_loss           | 364        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 234        |
# |    ep_rew_mean          | 482        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 485        |
# |    time_elapsed         | 15010      |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.09763697 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.126      |
# |    explained_variance   | 0.677      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 47.3       |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0133    |
# |    std                  | 0.238      |
# |    value_loss           | 283        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 231        |
# |    ep_rew_mean          | 478        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 486        |
# |    time_elapsed         | 15041      |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.04975372 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.125      |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 267        |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.239      |
# |    value_loss           | 715        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 482         |
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 487         |
# |    time_elapsed         | 15071       |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.054057673 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.123       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.238       |
# |    value_loss           | 469         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | 490        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 488        |
# |    time_elapsed         | 15102      |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.06646458 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.14       |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 142        |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.0211    |
# |    std                  | 0.238      |
# |    value_loss           | 371        |
# ----------------------------------------
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 233        |
# |    ep_rew_mean          | 496        |
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 489        |
# |    time_elapsed         | 15134      |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.05101531 |
# |    clip_fraction        | 0.373      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.169      |
# |    explained_variance   | 0.674      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 135        |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 0.235      |
# |    value_loss           | 480        |
# ----------------------------------------

# %%
model_v2.save("ppo_quadx_waypoints_1M")

import os
size_mb = os.path.getsize("ppo_quadx_waypoints_1M.zip") / 1e6
print(f"Model saved: ppo_quadx_waypoints_1M.zip ({size_mb:.2f} MB)")
# Out:
# Model saved: ppo_quadx_waypoints_1M.zip (0.18 MB)

# %%
from google.colab import files
files.download("ppo_quadx_waypoints_1M.zip")

# %%
from stable_baselines3 import PPO
model_v2 = PPO.load("ppo_quadx_waypoints_1M")
print("Model loaded.")
# Out:
# Model loaded.
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import numpy as np

eval_env = make_env()

NUM_EVAL_EPISODES = 20
episode_rewards, episode_targets, episode_oob, episode_lengths = [], [], [], []

for ep in range(NUM_EVAL_EPISODES):
    obs, info = eval_env.reset(seed=1000 + ep)
    terminated = truncated = False
    ep_reward, ep_len = 0.0, 0
    while not (terminated or truncated):
        action, _ = model_v2.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        ep_reward += reward
        ep_len += 1
    episode_rewards.append(ep_reward)
    episode_targets.append(info["num_targets_reached"])
    episode_oob.append(info["out_of_bounds"])
    episode_lengths.append(ep_len)

eval_env.close()

print(f"Episodes: {NUM_EVAL_EPISODES}")
print(f"Mean reward:        {np.mean(episode_rewards):.1f} +/- {np.std(episode_rewards):.1f}")
print(f"Mean targets:       {np.mean(episode_targets):.2f} (max: 4)")
print(f"Mean episode len:   {np.mean(episode_lengths):.1f}")
print(f"Out-of-bounds rate: {np.mean(episode_oob) * 100:.0f}%")
print(f"Targets per episode: {episode_targets}")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Episodes: 20
# Mean reward:        438.6 +/- 189.2
# Mean targets:       3.00 (max: 4)
# Mean episode len:   234.4
# Out-of-bounds rate: 5%
# Targets per episode: [3, 4, 4, 0, 4, 2, 3, 4, 4, 4, 4, 3, 2, 1, 3, 4, 3, 4, 3, 1]

# %%
import numpy as np

eval_env = make_env()

NUM_EVAL_EPISODES = 20
results = []

for ep in range(NUM_EVAL_EPISODES):
    obs, info = eval_env.reset(seed=1000 + ep)
    terminated = truncated = False
    ep_reward, ep_len = 0.0, 0
    while not (terminated or truncated):
        action, _ = model_v2.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        ep_reward += reward
        ep_len += 1
    results.append({
        "seed": 1000 + ep,
        "targets": info["num_targets_reached"],
        "reward": ep_reward,
        "length": ep_len,
        "out_of_bounds": info["out_of_bounds"],
        "collision": info["collision"],
    })

eval_env.close()

# Print detailed breakdown, sorted by targets reached
for r in sorted(results, key=lambda x: x["targets"]):
    print(f"seed={r['seed']:5d} | targets={r['targets']} | reward={r['reward']:7.1f} | "
          f"len={r['length']:4d} | oob={r['out_of_bounds']} | collision={r['collision']}")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# seed= 1003 | targets=0 | reward=  -67.0 | len=  60 | oob=False | collision=True
# seed= 1013 | targets=1 | reward=   59.8 | len= 128 | oob=False | collision=True
# seed= 1019 | targets=1 | reward=   58.9 | len= 126 | oob=False | collision=True
# seed= 1005 | targets=2 | reward=  419.6 | len= 302 | oob=False | collision=False
# seed= 1012 | targets=2 | reward=  289.6 | len= 269 | oob=True | collision=False
# seed= 1000 | targets=3 | reward=  526.8 | len= 302 | oob=False | collision=False
# seed= 1006 | targets=3 | reward=  492.1 | len= 302 | oob=False | collision=False
# seed= 1011 | targets=3 | reward=  527.3 | len= 302 | oob=False | collision=False
# seed= 1014 | targets=3 | reward=  501.6 | len= 302 | oob=False | collision=False
# seed= 1016 | targets=3 | reward=  541.5 | len= 302 | oob=False | collision=False
# seed= 1018 | targets=3 | reward=  509.9 | len= 302 | oob=False | collision=False
# seed= 1001 | targets=4 | reward=  559.8 | len= 226 | oob=False | collision=False
# seed= 1002 | targets=4 | reward=  561.5 | len= 285 | oob=False | collision=False
# seed= 1004 | targets=4 | reward=  603.6 | len= 297 | oob=False | collision=False
# seed= 1007 | targets=4 | reward=  557.2 | len= 243 | oob=False | collision=False
# seed= 1008 | targets=4 | reward=  534.6 | len= 199 | oob=False | collision=False
# seed= 1009 | targets=4 | reward=  552.5 | len= 220 | oob=False | collision=False
# seed= 1010 | targets=4 | reward=  545.1 | len= 252 | oob=False | collision=False
# seed= 1015 | targets=4 | reward=  484.2 | len= 109 | oob=False | collision=False
# seed= 1017 | targets=4 | reward=  512.7 | len= 160 | oob=False | collision=False

# %%
import torch
import numpy as np

def get_action_std(model, obs):
    """Extracts the Gaussian policy's std (per action dim) for a given obs."""
    obs_tensor, _ = model.policy.obs_to_tensor(obs)
    with torch.no_grad():
        distribution = model.policy.get_distribution(obs_tensor)
    std = distribution.distribution.stddev.cpu().numpy()[0]  # shape (4,)
    return std

def run_episode_with_uncertainty(model, env, seed):
    obs, info = env.reset(seed=seed)
    terminated = truncated = False
    history = []
    step = 0
    while not (terminated or truncated):
        std = get_action_std(model, obs)
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        history.append({"step": step, "mean_std": std.mean(), "reward": reward})
        step += 1
    return history, info

eval_env = make_env()

# Known crash seed
crash_history, crash_info = run_episode_with_uncertainty(model_v2, eval_env, seed=1003)

# Known success seed
success_history, success_info = run_episode_with_uncertainty(model_v2, eval_env, seed=1001)

eval_env.close()

print(f"CRASH episode (seed 1003, targets={crash_info['num_targets_reached']}), last 15 steps:")
for h in crash_history[-15:]:
    print(f"  step={h['step']:3d}  mean_std={h['mean_std']:.4f}  reward={h['reward']:.2f}")

print(f"\nSUCCESS episode (seed 1001, targets={success_info['num_targets_reached']}), last 15 steps:")
for h in success_history[-15:]:
    print(f"  step={h['step']:3d}  mean_std={h['mean_std']:.4f}  reward={h['reward']:.2f}")
# Out:
#
#
# CRASH episode (seed 1003, targets=0), last 15 steps:
#   step= 45  mean_std=0.2348  reward=0.79
#   step= 46  mean_std=0.2348  reward=0.86
#   step= 47  mean_std=0.2348  reward=0.87
#   step= 48  mean_std=0.2348  reward=0.94
#   step= 49  mean_std=0.2348  reward=0.94
#   step= 50  mean_std=0.2348  reward=0.99
#   step= 51  mean_std=0.2348  reward=1.01
#   step= 52  mean_std=0.2348  reward=1.08
#   step= 53  mean_std=0.2348  reward=1.09
#   step= 54  mean_std=0.2348  reward=1.24
#   step= 55  mean_std=0.2348  reward=1.27
#   step= 56  mean_std=0.2348  reward=1.45
#   step= 57  mean_std=0.2348  reward=1.60
#   step= 58  mean_std=0.2348  reward=1.71
#   step= 59  mean_std=0.2348  reward=-99.86
#
# SUCCESS episode (seed 1001, targets=4), last 15 steps:
#   step=211  mean_std=0.2348  reward=0.97
#   step=212  mean_std=0.2348  reward=0.99
#   step=213  mean_std=0.2348  reward=1.01
#   step=214  mean_std=0.2348  reward=1.04
#   step=215  mean_std=0.2348  reward=1.10
#   step=216  mean_std=0.2348  reward=1.15
#   step=217  mean_std=0.2348  reward=1.21
#   step=218  mean_std=0.2348  reward=1.27
#   step=219  mean_std=0.2348  reward=1.32
#   step=220  mean_std=0.2348  reward=1.38
#   step=221  mean_std=0.2348  reward=1.51
#   step=222  mean_std=0.2348  reward=1.62
#   step=223  mean_std=0.2348  reward=1.73
#   step=224  mean_std=0.2348  reward=1.83
#   step=225  mean_std=0.2348  reward=100.00

# %%
import torch
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.policies import ActorCriticPolicy


class DropoutMlpExtractor(nn.Module):
    """Same (64,64) architecture as SB3's default extractor, but with dropout
    layers inserted so MC Dropout can be used at inference time."""

    def __init__(self, feature_dim, dropout_rate=0.1):
        super().__init__()
        hidden = 64

        self.policy_net = nn.Sequential(
            nn.Linear(feature_dim, hidden), nn.Tanh(), nn.Dropout(dropout_rate),
            nn.Linear(hidden, hidden), nn.Tanh(), nn.Dropout(dropout_rate),
        )
        self.value_net = nn.Sequential(
            nn.Linear(feature_dim, hidden), nn.Tanh(), nn.Dropout(dropout_rate),
            nn.Linear(hidden, hidden), nn.Tanh(), nn.Dropout(dropout_rate),
        )

        self.latent_dim_pi = hidden
        self.latent_dim_vf = hidden

    def forward(self, features):
        return self.forward_actor(features), self.forward_critic(features)

    def forward_actor(self, features):
        return self.policy_net(features)

    def forward_critic(self, features):
        return self.value_net(features)


class DropoutActorCriticPolicy(ActorCriticPolicy):
    """ActorCriticPolicy using our dropout-enabled extractor instead of the default."""

    def _build_mlp_extractor(self) -> None:
        self.mlp_extractor = DropoutMlpExtractor(self.features_dim, dropout_rate=0.1)

# %%
# Build a new model with the dropout-enabled policy
temp_env = make_env()
new_model = PPO(DropoutActorCriticPolicy, temp_env, verbose=0, device="cpu", seed=0)


def copy_linear_weights(source_seq, target_seq):
    """Copies weights between two nn.Sequential modules, matching only Linear layers in order."""
    source_linears = [m for m in source_seq if isinstance(m, nn.Linear)]
    target_linears = [m for m in target_seq if isinstance(m, nn.Linear)]
    assert len(source_linears) == len(target_linears), "Layer count mismatch"
    for src, tgt in zip(source_linears, target_linears):
        tgt.load_state_dict(src.state_dict())


# Transfer the learned weights from the clean 1M model into the dropout policy
copy_linear_weights(model_v2.policy.mlp_extractor.policy_net, new_model.policy.mlp_extractor.policy_net)
copy_linear_weights(model_v2.policy.mlp_extractor.value_net, new_model.policy.mlp_extractor.value_net)
new_model.policy.action_net.load_state_dict(model_v2.policy.action_net.state_dict())
new_model.policy.value_net.load_state_dict(model_v2.policy.value_net.state_dict())
new_model.policy.log_std.data.copy_(model_v2.policy.log_std.data)

temp_env.close()
print("Weights transferred from clean 1M model into dropout-enabled policy.")
# Out:
# Weights transferred from clean 1M model into dropout-enabled policy.

# %%
test_env = make_env()
obs, info = test_env.reset(seed=1003)
test_env.close()

obs_tensor, _ = new_model.policy.obs_to_tensor(obs)

# Enable dropout at inference time (normally it's off during eval)
new_model.policy.mlp_extractor.train()

with torch.no_grad():
    actions = []
    for _ in range(5):
        dist = new_model.policy.get_distribution(obs_tensor)
        action = dist.distribution.mean  # mean action under current dropout mask
        actions.append(action.cpu().numpy()[0])

for i, a in enumerate(actions):
    print(f"Pass {i}: {a}")
# Out:
#
# Pass 0: [ 4.507501   -2.1022546   0.92421365 -0.45563146]
# Pass 1: [ 3.8936064  -2.3339694   1.5888574  -0.09651639]
# Pass 2: [ 4.2336187  -2.2068958   1.6870081   0.44169056]
# Pass 3: [ 5.1526217  -1.5475966   1.3047118  -0.16308388]
# Pass 4: [ 5.729922  -1.9996843  1.3754021 -0.5701534]

# %%
# Compare: raw mean action from the ORIGINAL (non-dropout) trained model, same state
obs_tensor_orig, _ = model_v2.policy.obs_to_tensor(obs)

with torch.no_grad():
    dist_orig = model_v2.policy.get_distribution(obs_tensor_orig)
    mean_action_orig = dist_orig.distribution.mean.cpu().numpy()[0]

print("Original model_v2 raw mean action:", mean_action_orig)

# Also check dropout-model with dropout DISABLED (eval mode) for a clean comparison
new_model.policy.mlp_extractor.eval()
with torch.no_grad():
    dist_new_eval = new_model.policy.get_distribution(obs_tensor)
    mean_action_new_eval = dist_new_eval.distribution.mean.cpu().numpy()[0]

print("Dropout model (dropout OFF) raw mean action:", mean_action_new_eval)
# Out:
# Original model_v2 raw mean action: [ 4.860271   -2.3819783   1.2747233  -0.08841026]
# Dropout model (dropout OFF) raw mean action: [ 4.860271   -2.3819785   1.274723   -0.08841051]

# %%
# Rebuild clean: fresh dropout policy with weights from the untouched 1M model
temp_env = make_env()
new_model = PPO(DropoutActorCriticPolicy, temp_env, verbose=0, device="cpu", seed=0)

copy_linear_weights(model_v2.policy.mlp_extractor.policy_net, new_model.policy.mlp_extractor.policy_net)
copy_linear_weights(model_v2.policy.mlp_extractor.value_net, new_model.policy.mlp_extractor.value_net)
new_model.policy.action_net.load_state_dict(model_v2.policy.action_net.state_dict())
new_model.policy.value_net.load_state_dict(model_v2.policy.value_net.state_dict())
new_model.policy.log_std.data.copy_(model_v2.policy.log_std.data)

new_model.policy.mlp_extractor.eval()  # dropout OFF by default
temp_env.close()

# Verify transfer is clean
obs_tensor, _ = new_model.policy.obs_to_tensor(obs)
with torch.no_grad():
    check = new_model.policy.get_distribution(obs_tensor).distribution.mean.cpu().numpy()[0]
print("Should match original:", check)
# Out:
# Should match original: [ 4.860271   -2.3819785   1.274723   -0.08841051]

# %%
import numpy as np
import torch


def get_mc_dropout_uncertainty(model, obs, n_samples=20):
    """Runs n stochastic forward passes with dropout active, returns the
    spread of the resulting mean actions — our epistemic uncertainty signal."""
    obs_tensor, _ = model.policy.obs_to_tensor(obs)

    model.policy.mlp_extractor.train()   # enable dropout
    actions = []
    with torch.no_grad():
        for _ in range(n_samples):
            dist = model.policy.get_distribution(obs_tensor)
            actions.append(dist.distribution.mean.cpu().numpy()[0])
    model.policy.mlp_extractor.eval()    # restore deterministic mode

    actions = np.array(actions)          # (n_samples, action_dim)
    return actions.std(axis=0).mean()    # scalar uncertainty score


def run_episode_with_uncertainty(model, env, seed, n_samples=20):
    """Runs one episode using the DETERMINISTIC policy, logging MC-dropout
    uncertainty at each step (measurement only — does not affect actions)."""
    obs, info = env.reset(seed=seed)
    terminated = truncated = False
    history = []
    step = 0

    while not (terminated or truncated):
        uncertainty = get_mc_dropout_uncertainty(model, obs, n_samples)

        # Act deterministically (dropout is off here — same policy as the 1M model)
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)

        history.append({"step": step, "uncertainty": uncertainty, "reward": reward})
        step += 1

    return history, info


eval_env = make_env()

crash_hist, crash_info = run_episode_with_uncertainty(new_model, eval_env, seed=1003)
success_hist, success_info = run_episode_with_uncertainty(new_model, eval_env, seed=1001)

eval_env.close()

print(f"CRASH (seed 1003, targets={crash_info['num_targets_reached']}, "
      f"collision={crash_info['collision']}), last 15 steps:")
for h in crash_hist[-15:]:
    print(f"  step={h['step']:3d}  uncertainty={h['uncertainty']:.4f}  reward={h['reward']:7.2f}")

print(f"\nSUCCESS (seed 1001, targets={success_info['num_targets_reached']}), last 15 steps:")
for h in success_hist[-15:]:
    print(f"  step={h['step']:3d}  uncertainty={h['uncertainty']:.4f}  reward={h['reward']:7.2f}")

print(f"\nCRASH mean uncertainty:   {np.mean([h['uncertainty'] for h in crash_hist]):.4f}")
print(f"SUCCESS mean uncertainty: {np.mean([h['uncertainty'] for h in success_hist]):.4f}")
# Out:
#
#
# CRASH (seed 1003, targets=0, collision=True), last 15 steps:
#   step= 45  uncertainty=0.4987  reward=   0.79
#   step= 46  uncertainty=0.5096  reward=   0.86
#   step= 47  uncertainty=0.4629  reward=   0.87
#   step= 48  uncertainty=0.5085  reward=   0.94
#   step= 49  uncertainty=0.4982  reward=   0.94
#   step= 50  uncertainty=0.4450  reward=   0.99
#   step= 51  uncertainty=0.4348  reward=   1.01
#   step= 52  uncertainty=0.5563  reward=   1.08
#   step= 53  uncertainty=0.5015  reward=   1.09
#   step= 54  uncertainty=0.4446  reward=   1.24
#   step= 55  uncertainty=0.5355  reward=   1.27
#   step= 56  uncertainty=0.6165  reward=   1.45
#   step= 57  uncertainty=0.4498  reward=   1.60
#   step= 58  uncertainty=0.4765  reward=   1.71
#   step= 59  uncertainty=0.5149  reward= -99.86
#
# SUCCESS (seed 1001, targets=3), last 15 steps:
#   step=287  uncertainty=0.4989  reward=   1.57
#   step=288  uncertainty=0.4804  reward=   1.62
#   step=289  uncertainty=0.5282  reward=   1.66
#   step=290  uncertainty=0.4561  reward=   1.70
#   step=291  uncertainty=0.4674  reward=   1.73
#   step=292  uncertainty=0.5200  reward=   1.75
#   step=293  uncertainty=0.5921  reward=   1.76
#   step=294  uncertainty=0.4321  reward=   1.77
#   step=295  uncertainty=0.5166  reward=   1.78
#   step=296  uncertainty=0.5448  reward=   1.78
#   step=297  uncertainty=0.4586  reward=   1.76
#   step=298  uncertainty=0.5804  reward=   1.75
#   step=299  uncertainty=0.5791  reward=   1.73
#   step=300  uncertainty=0.5020  reward=   1.69
#   step=301  uncertainty=0.4330  reward=   0.34
#
# CRASH mean uncertainty:   0.5050
# SUCCESS mean uncertainty: 0.4776

# %%
import numpy as np

eval_env = make_env()
episode_summaries = []

for ep in range(20):
    seed = 1000 + ep
    hist, info = run_episode_with_uncertainty(new_model, eval_env, seed, n_samples=15)
    episode_summaries.append({
        "seed": seed,
        "targets": info["num_targets_reached"],
        "collision": info["collision"],
        "oob": info["out_of_bounds"],
        "mean_uncertainty": np.mean([h["uncertainty"] for h in hist]),
        "max_uncertainty": np.max([h["uncertainty"] for h in hist]),
        "last5_uncertainty": np.mean([h["uncertainty"] for h in hist[-5:]]),
    })

eval_env.close()

for s in sorted(episode_summaries, key=lambda x: x["targets"]):
    print(f"seed={s['seed']:5d} | targets={s['targets']} | collision={s['collision']} | "
          f"mean_unc={s['mean_uncertainty']:.4f} | max_unc={s['max_uncertainty']:.4f} | "
          f"last5_unc={s['last5_uncertainty']:.4f}")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# seed= 1003 | targets=0 | collision=True | mean_unc=0.5077 | max_unc=0.6700 | last5_unc=0.4732
# seed= 1019 | targets=1 | collision=True | mean_unc=0.4926 | max_unc=0.6709 | last5_unc=0.4697
# seed= 1005 | targets=2 | collision=False | mean_unc=0.4856 | max_unc=0.6497 | last5_unc=0.4868
# seed= 1011 | targets=2 | collision=False | mean_unc=0.4933 | max_unc=0.6585 | last5_unc=0.4674
# seed= 1012 | targets=2 | collision=False | mean_unc=0.4925 | max_unc=0.6579 | last5_unc=0.4820
# seed= 1013 | targets=2 | collision=False | mean_unc=0.4929 | max_unc=0.6934 | last5_unc=0.4832
# seed= 1000 | targets=3 | collision=True | mean_unc=0.4963 | max_unc=0.6760 | last5_unc=0.4950
# seed= 1001 | targets=3 | collision=False | mean_unc=0.4702 | max_unc=0.7382 | last5_unc=0.5290
# seed= 1016 | targets=3 | collision=False | mean_unc=0.4600 | max_unc=0.6485 | last5_unc=0.4115
# seed= 1018 | targets=3 | collision=False | mean_unc=0.4835 | max_unc=0.6443 | last5_unc=0.4982
# seed= 1002 | targets=4 | collision=False | mean_unc=0.4971 | max_unc=0.7080 | last5_unc=0.4824
# seed= 1004 | targets=4 | collision=False | mean_unc=0.4923 | max_unc=0.7912 | last5_unc=0.4429
# seed= 1006 | targets=4 | collision=False | mean_unc=0.4891 | max_unc=0.6432 | last5_unc=0.4578
# seed= 1007 | targets=4 | collision=False | mean_unc=0.4883 | max_unc=0.6987 | last5_unc=0.4619
# seed= 1008 | targets=4 | collision=False | mean_unc=0.4577 | max_unc=0.6042 | last5_unc=0.4035
# seed= 1009 | targets=4 | collision=False | mean_unc=0.4725 | max_unc=0.6552 | last5_unc=0.4742
# seed= 1010 | targets=4 | collision=False | mean_unc=0.4892 | max_unc=0.6882 | last5_unc=0.5045
# seed= 1014 | targets=4 | collision=False | mean_unc=0.4934 | max_unc=0.7427 | last5_unc=0.4688
# seed= 1015 | targets=4 | collision=False | mean_unc=0.4578 | max_unc=0.5896 | last5_unc=0.4240
# seed= 1017 | targets=4 | collision=False | mean_unc=0.4652 | max_unc=0.6267 | last5_unc=0.4631
